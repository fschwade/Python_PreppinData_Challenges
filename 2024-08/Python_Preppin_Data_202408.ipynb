# %% [markdown]
# # Preppin' Data
# ## 2024: Week 8 - Prep Air Loyalty
# **Created by:** Jenny Martin | [Challenge Link](https://preppindata.blogspot.com/2024/02/2024-week-8-prep-air-loyalty.html)

# %% [markdown]
# For this week's challenge, Prep Air have asked for some What If? Analysis. <br>
# They're considering 2 different systems for rewarding customer loyalty and want to understand how that might impact cost and how many customers might benefit from the program.

# %%
# Input the csv file
import pandas as pd
import numpy as np
customers = pd.read_csv("Prep Air Updated Customers.csv", parse_dates=["First Flight", "Last Date Flown"]).sort_index()
customers
# Out:
#       Customer ID first_name  last_name                      email  gender  \
# 0               1     Denyse     Gebuhr       dgebuhr0@vinaora.com  Female
# 1               2      Keene   Devennie     kdevennie1@plala.or.jp    Male
# 2               3      Tyler    McGrail          tmcgrail2@nyu.edu    Male
# 3               4      Drusi     Ibeson     dibeson3@hostgator.com  Female
# 4               5   Stanwood   Seacroft  sseacroft4@wikispaces.com    Male
# ...           ...        ...        ...                        ...     ...
# 9994         9995    Hesther  Braidwood   hbraidwoodrm@reuters.com  Female
# 9995         9996     Jelene   Dodgshun  jdodgshunrn@angelfire.com  Female
# 9996         9997        Ira       Duff      iduffro@delicious.com    Male
# 9997         9998    Yalonda  Carrivick   ycarrivickrp@samsung.com  Female
# 9998         9999      Netta     Course       ncourserq@weebly.com  Female
#
#      First Flight Last Date Flown  Number of Flights
# 0      2023-01-05      2023-01-05                  1
# 1      2023-10-05      2023-10-05                  1
# 2      2022-07-18      2023-11-09                 27
# 3      2022-05-28      2023-11-22                 32
# 4      2022-08-19      2023-12-23                  5
# ...           ...             ...                ...
# 9994   2023-09-09      2024-01-19                 29
# 9995   2022-03-16      2023-09-16                 22
# 9996   2022-02-08      2023-11-26                 32
# 9997   2022-06-18      2023-03-12                 14
# 9998   2022-03-08      2023-06-29                 26
#
# [9999 rows x 8 columns]

# %%
# Input the xlsx file
tier = pd.read_excel("Prep Air Loyalty.xlsx", sheet_name="Prep Air Loyalty")
tier
# Out:
#     Tier Grouping Number of Flights    Tier  \
# 0               5               1-4  Tier 0
# 1               5               5-9  Tier 1
# 2               5             10-14  Tier 2
# 3               5             15-19  Tier 3
# 4               5             20-24  Tier 4
# 5               5             25-29  Tier 5
# 6               5               30+  Tier 6
# 7              10               1-9  Tier 0
# 8              10             10-19  Tier 1
# 9              10             20-29  Tier 2
# 10             10               30+  Tier 3
#
#                                              Benefits
# 0                                                 NaN
# 1                                Early Seat Selection
# 2                                 Free Seat Selection
# 3                        Priority Bag Drop & Boarding
# 4                              First Checked Bag Free
# 5                           First Class Lounge Access
# 6   First Class Lounge Access for 1 Guest, , £250 ...
# 7                                                 NaN
# 8           Free Seat Selection, Early Seat Selection
# 9   First Checked Bag Free, Priority Bag Drop & Bo...
# 10  First Class Lounge Access, First Class Lounge ...

# %%
costs = pd.read_excel("Prep Air Loyalty.xlsx", sheet_name="Costings")
costs
# Out:
#                                  Benefit            Cost
# 0                   Early Seat Selection               0
# 1                    Free Seat Selection  £15 per flight
# 2                 First Checked Bag Free  £35 per flight
# 3           Priority Bag Drop & Boarding               0
# 4              First Class Lounge Access  £50 per flight
# 5  First Class Lounge Access for 1 Guest  £50 per flight
# 6            £250 off a flight each Year     £250 a year

# %%
# To be part of either Prep Air Loyalty Scheme, Customers must have flown in the last year (on or after 21st February 2023)
flown_this_year = customers[customers["Last Date Flown"].between("2023-02-21", "2024-02-20")].copy()
flown_this_year.head()
# Out:
#    Customer ID first_name last_name                      email   gender  \
# 1            2      Keene  Devennie     kdevennie1@plala.or.jp     Male
# 2            3      Tyler   McGrail          tmcgrail2@nyu.edu     Male
# 3            4      Drusi    Ibeson     dibeson3@hostgator.com   Female
# 4            5   Stanwood  Seacroft  sseacroft4@wikispaces.com     Male
# 5            6     Kelcey     McCaw            kmccaw5@mlb.com  Agender
#
#   First Flight Last Date Flown  Number of Flights
# 1   2023-10-05      2023-10-05                  1
# 2   2022-07-18      2023-11-09                 27
# 3   2022-05-28      2023-11-22                 32
# 4   2022-08-19      2023-12-23                  5
# 5   2023-02-28      2023-02-28                  1

# %% [markdown]
# Create a parameter so that the number of flights a customer has taken is either bucketed into groups of 5 or groups to 10 <br>
# e.g. if the parameter selected is 5, the groupings will be 1-4, 5-9 etc<br>
# if the parameter selected is 10, the groupings will be 1-9, 10-19 etc<br>

# %% [markdown]
# Choose one of the parameters:

# %%
parameter = 5

# %%
# parameter = 10

# %%
# Create a field to categorize customers based on the selected parameter, called Tier
flown_this_year["Tier"] = flown_this_year['Number of Flights'] // parameter
flown_this_year["Tier Grouping"] = parameter
flown_this_year.head()
# Out:
#    Customer ID first_name last_name                      email   gender  \
# 1            2      Keene  Devennie     kdevennie1@plala.or.jp     Male
# 2            3      Tyler   McGrail          tmcgrail2@nyu.edu     Male
# 3            4      Drusi    Ibeson     dibeson3@hostgator.com   Female
# 4            5   Stanwood  Seacroft  sseacroft4@wikispaces.com     Male
# 5            6     Kelcey     McCaw            kmccaw5@mlb.com  Agender
#
#   First Flight Last Date Flown  Number of Flights  Tier  Tier Grouping
# 1   2023-10-05      2023-10-05                  1     0              5
# 2   2022-07-18      2023-11-09                 27     5              5
# 3   2022-05-28      2023-11-22                 32     6              5
# 4   2022-08-19      2023-12-23                  5     1              5
# 5   2023-02-28      2023-02-28                  1     0              5

# %%
# Estimate the average number of flights a customer takes per year
flown_this_year["Years as Customer"] = flown_this_year["Last Date Flown"].dt.year - flown_this_year["First Flight"].dt.year + 1
flown_this_year["Avg Flights per Year"] = flown_this_year["Number of Flights"] / flown_this_year["Years as Customer"]
flown_this_year.head()
# Out:
#    Customer ID first_name last_name                      email   gender  \
# 1            2      Keene  Devennie     kdevennie1@plala.or.jp     Male
# 2            3      Tyler   McGrail          tmcgrail2@nyu.edu     Male
# 3            4      Drusi    Ibeson     dibeson3@hostgator.com   Female
# 4            5   Stanwood  Seacroft  sseacroft4@wikispaces.com     Male
# 5            6     Kelcey     McCaw            kmccaw5@mlb.com  Agender
#
#   First Flight Last Date Flown  Number of Flights  Tier  Tier Grouping  \
# 1   2023-10-05      2023-10-05                  1     0              5
# 2   2022-07-18      2023-11-09                 27     5              5
# 3   2022-05-28      2023-11-22                 32     6              5
# 4   2022-08-19      2023-12-23                  5     1              5
# 5   2023-02-28      2023-02-28                  1     0              5
#
#    Years as Customer  Avg Flights per Year
# 1                  1                   1.0
# 2                  2                  13.5
# 3                  2                  16.0
# 4                  2                   2.5
# 5                  1                   1.0

# %%
# Filter the Prep Air Loyalty dataset to the selected parameter value
tier[tier["Tier Grouping"] == parameter]
tier
# Out:
#     Tier Grouping Number of Flights    Tier  \
# 0               5               1-4  Tier 0
# 1               5               5-9  Tier 1
# 2               5             10-14  Tier 2
# 3               5             15-19  Tier 3
# 4               5             20-24  Tier 4
# 5               5             25-29  Tier 5
# 6               5               30+  Tier 6
# 7              10               1-9  Tier 0
# 8              10             10-19  Tier 1
# 9              10             20-29  Tier 2
# 10             10               30+  Tier 3
#
#                                              Benefits
# 0                                                 NaN
# 1                                Early Seat Selection
# 2                                 Free Seat Selection
# 3                        Priority Bag Drop & Boarding
# 4                              First Checked Bag Free
# 5                           First Class Lounge Access
# 6   First Class Lounge Access for 1 Guest, , £250 ...
# 7                                                 NaN
# 8           Free Seat Selection, Early Seat Selection
# 9   First Checked Bag Free, Priority Bag Drop & Bo...
# 10  First Class Lounge Access, First Class Lounge ...

# %%
tier["Tier"] = tier["Tier"].str.split(" ").str.get(1)
tier["Tier"] = tier["Tier"].astype(int)
tier
# Out:
#     Tier Grouping Number of Flights  Tier  \
# 0               5               1-4     0
# 1               5               5-9     1
# 2               5             10-14     2
# 3               5             15-19     3
# 4               5             20-24     4
# 5               5             25-29     5
# 6               5               30+     6
# 7              10               1-9     0
# 8              10             10-19     1
# 9              10             20-29     2
# 10             10               30+     3
#
#                                              Benefits
# 0                                                 NaN
# 1                                Early Seat Selection
# 2                                 Free Seat Selection
# 3                        Priority Bag Drop & Boarding
# 4                              First Checked Bag Free
# 5                           First Class Lounge Access
# 6   First Class Lounge Access for 1 Guest, , £250 ...
# 7                                                 NaN
# 8           Free Seat Selection, Early Seat Selection
# 9   First Checked Bag Free, Priority Bag Drop & Bo...
# 10  First Class Lounge Access, First Class Lounge ...

# %% [markdown]
# Join the Prep Air Loyalty to the Customer dataset in a way that each customer also experiences the benefits of lower Tiers<br>
# e.g. a Tier 2 customer gets all the benefits of Tier 0, Tier 1 and Tier 2

# %%
benefits = flown_this_year.merge(tier, how="left", on=["Tier Grouping"])
benefits = benefits[benefits["Tier_y"] <= benefits["Tier_x"]]
benefits = benefits.dropna(subset=["Benefits"])
benefits
# Out:
#        Customer ID first_name last_name                 email  gender  \
# 8                3      Tyler   McGrail     tmcgrail2@nyu.edu    Male
# 9                3      Tyler   McGrail     tmcgrail2@nyu.edu    Male
# 10               3      Tyler   McGrail     tmcgrail2@nyu.edu    Male
# 11               3      Tyler   McGrail     tmcgrail2@nyu.edu    Male
# 12               3      Tyler   McGrail     tmcgrail2@nyu.edu    Male
# ...            ...        ...       ...                   ...     ...
# 61965         9999      Netta    Course  ncourserq@weebly.com  Female
# 61966         9999      Netta    Course  ncourserq@weebly.com  Female
# 61967         9999      Netta    Course  ncourserq@weebly.com  Female
# 61968         9999      Netta    Course  ncourserq@weebly.com  Female
# 61969         9999      Netta    Course  ncourserq@weebly.com  Female
#
#       First Flight Last Date Flown  Number of Flights_x  Tier_x  \
# 8       2022-07-18      2023-11-09                   27       5
# 9       2022-07-18      2023-11-09                   27       5
# 10      2022-07-18      2023-11-09                   27       5
# 11      2022-07-18      2023-11-09                   27       5
# 12      2022-07-18      2023-11-09                   27       5
# ...            ...             ...                  ...     ...
# 61965   2022-03-08      2023-06-29                   26       5
# 61966   2022-03-08      2023-06-29                   26       5
# 61967   2022-03-08      2023-06-29                   26       5
# 61968   2022-03-08      2023-06-29                   26       5
# 61969   2022-03-08      2023-06-29                   26       5
#
#        Tier Grouping  Years as Customer  Avg Flights per Year  \
# 8                  5                  2                  13.5
# 9                  5                  2                  13.5
# 10                 5                  2                  13.5
# 11                 5                  2                  13.5
# 12                 5                  2                  13.5
# ...              ...                ...                   ...
# 61965              5                  2                  13.0
# 61966              5                  2                  13.0
# 61967              5                  2                  13.0
# 61968              5                  2                  13.0
# 61969              5                  2                  13.0
#
#       Number of Flights_y  Tier_y                      Benefits
# 8                     5-9       1          Early Seat Selection
# 9                   10-14       2           Free Seat Selection
# 10                  15-19       3  Priority Bag Drop & Boarding
# 11                  20-24       4        First Checked Bag Free
# 12                  25-29       5     First Class Lounge Access
# ...                   ...     ...                           ...
# 61965                 5-9       1          Early Seat Selection
# 61966               10-14       2           Free Seat Selection
# 61967               15-19       3  Priority Bag Drop & Boarding
# 61968               20-24       4        First Checked Bag Free
# 61969               25-29       5     First Class Lounge Access
#
# [22288 rows x 15 columns]

# %%
# Join on the Costing dataset
benefit_costs = benefits.merge(costs, how="left", left_on="Benefits", right_on="Benefit").drop(columns=["Benefit", "Number of Flights_y", "Tier_x"])
benefit_costs.head()
# Out:
#    Customer ID first_name last_name              email gender First Flight  \
# 0            3      Tyler   McGrail  tmcgrail2@nyu.edu   Male   2022-07-18
# 1            3      Tyler   McGrail  tmcgrail2@nyu.edu   Male   2022-07-18
# 2            3      Tyler   McGrail  tmcgrail2@nyu.edu   Male   2022-07-18
# 3            3      Tyler   McGrail  tmcgrail2@nyu.edu   Male   2022-07-18
# 4            3      Tyler   McGrail  tmcgrail2@nyu.edu   Male   2022-07-18
#
#   Last Date Flown  Number of Flights_x  Tier Grouping  Years as Customer  \
# 0      2023-11-09                   27              5                  2
# 1      2023-11-09                   27              5                  2
# 2      2023-11-09                   27              5                  2
# 3      2023-11-09                   27              5                  2
# 4      2023-11-09                   27              5                  2
#
#    Avg Flights per Year  Tier_y                      Benefits            Cost
# 0                  13.5       1          Early Seat Selection               0
# 1                  13.5       2           Free Seat Selection  £15 per flight
# 2                  13.5       3  Priority Bag Drop & Boarding               0
# 3                  13.5       4        First Checked Bag Free  £35 per flight
# 4                  13.5       5     First Class Lounge Access  £50 per flight

# %%
# formatting the Cost column to be just values
benefit_costs["Cost"] = benefit_costs["Cost"].str.split(" ").str.get(0).str.lstrip('£').fillna(0).astype(int)
benefit_costs.head()
# Out:
#    Customer ID first_name last_name              email gender First Flight  \
# 0            3      Tyler   McGrail  tmcgrail2@nyu.edu   Male   2022-07-18
# 1            3      Tyler   McGrail  tmcgrail2@nyu.edu   Male   2022-07-18
# 2            3      Tyler   McGrail  tmcgrail2@nyu.edu   Male   2022-07-18
# 3            3      Tyler   McGrail  tmcgrail2@nyu.edu   Male   2022-07-18
# 4            3      Tyler   McGrail  tmcgrail2@nyu.edu   Male   2022-07-18
#
#   Last Date Flown  Number of Flights_x  Tier Grouping  Years as Customer  \
# 0      2023-11-09                   27              5                  2
# 1      2023-11-09                   27              5                  2
# 2      2023-11-09                   27              5                  2
# 3      2023-11-09                   27              5                  2
# 4      2023-11-09                   27              5                  2
#
#    Avg Flights per Year  Tier_y                      Benefits  Cost
# 0                  13.5       1          Early Seat Selection     0
# 1                  13.5       2           Free Seat Selection    15
# 2                  13.5       3  Priority Bag Drop & Boarding     0
# 3                  13.5       4        First Checked Bag Free    35
# 4                  13.5       5     First Class Lounge Access    50

# %% [markdown]
# Calculate the Yearly Cost of each Benefit
# e.g. if the Benefit Cost is per flight tahen make sure to multiply it by the Avg Number of Flights that customer takes in a year

# %%
flight_benefits = [
    "Early Seat Selection",
    "First Checked Bag Free",
    "Free Seat Selection",
    "Priority Bag Drop & Boarding"
]

def yearly_costs(customer_benefits):
    if customer_benefits["Benefits"] in flight_benefits:
        return customer_benefits["Cost"] * customer_benefits["Avg Flights per Year"]
    else:
        return customer_benefits["Cost"]

benefit_costs["Yearly Cost"] = benefit_costs.apply(yearly_costs, axis=1)
benefit_costs
# Out:
#        Customer ID first_name last_name                 email  gender  \
# 0                3      Tyler   McGrail     tmcgrail2@nyu.edu    Male
# 1                3      Tyler   McGrail     tmcgrail2@nyu.edu    Male
# 2                3      Tyler   McGrail     tmcgrail2@nyu.edu    Male
# 3                3      Tyler   McGrail     tmcgrail2@nyu.edu    Male
# 4                3      Tyler   McGrail     tmcgrail2@nyu.edu    Male
# ...            ...        ...       ...                   ...     ...
# 22283         9999      Netta    Course  ncourserq@weebly.com  Female
# 22284         9999      Netta    Course  ncourserq@weebly.com  Female
# 22285         9999      Netta    Course  ncourserq@weebly.com  Female
# 22286         9999      Netta    Course  ncourserq@weebly.com  Female
# 22287         9999      Netta    Course  ncourserq@weebly.com  Female
#
#       First Flight Last Date Flown  Number of Flights_x  Tier Grouping  \
# 0       2022-07-18      2023-11-09                   27              5
# 1       2022-07-18      2023-11-09                   27              5
# 2       2022-07-18      2023-11-09                   27              5
# 3       2022-07-18      2023-11-09                   27              5
# 4       2022-07-18      2023-11-09                   27              5
# ...            ...             ...                  ...            ...
# 22283   2022-03-08      2023-06-29                   26              5
# 22284   2022-03-08      2023-06-29                   26              5
# 22285   2022-03-08      2023-06-29                   26              5
# 22286   2022-03-08      2023-06-29                   26              5
# 22287   2022-03-08      2023-06-29                   26              5
#
#        Years as Customer  Avg Flights per Year  Tier_y  \
# 0                      2                  13.5       1
# 1                      2                  13.5       2
# 2                      2                  13.5       3
# 3                      2                  13.5       4
# 4                      2                  13.5       5
# ...                  ...                   ...     ...
# 22283                  2                  13.0       1
# 22284                  2                  13.0       2
# 22285                  2                  13.0       3
# 22286                  2                  13.0       4
# 22287                  2                  13.0       5
#
#                            Benefits  Cost  Yearly Cost
# 0              Early Seat Selection     0          0.0
# 1               Free Seat Selection    15        202.5
# 2      Priority Bag Drop & Boarding     0          0.0
# 3            First Checked Bag Free    35        472.5
# 4         First Class Lounge Access    50         50.0
# ...                             ...   ...          ...
# 22283          Early Seat Selection     0          0.0
# 22284           Free Seat Selection    15        195.0
# 22285  Priority Bag Drop & Boarding     0          0.0
# 22286        First Checked Bag Free    35        455.0
# 22287     First Class Lounge Access    50         50.0
#
# [22288 rows x 15 columns]

# %%
# Total up the Yearly Cost for each Tier

tier_pivot = benefit_costs.pivot_table(index="Tier_y", values="Yearly Cost", aggfunc="sum")
tier_pivot.head()
# Out:
#          Yearly Cost
# Tier_y
# 1       0.000000e+00
# 2       1.075660e+06
# 3       0.000000e+00
# 4       1.739372e+06
# 5       9.595000e+04

# %%
# and count the Number of Customers in Each Tier

tier_pivot_2 = benefit_costs.pivot_table(index="Tier_y", values="Customer ID", aggfunc="nunique").rename(columns={"Customer ID": "Number of Customers"})
tier_pivot_2.head()
# Out:
#         Number of Customers
# Tier_y
# 1                      6764
# 2                      5526
# 3                      4309
# 4                      3089
# 5                      1919

# %% [markdown]
# ## Output 1
# #### 5 Tier Grouping Output
# <br>
# 6 rows<br>
# 3 fields:<br>
# - Tier<br>
# - Year Cost<br>
# - Number of Customers<br>

# %%
# joining both pivot tables
# Output the data

output = tier_pivot.merge(tier_pivot_2, how="left", left_index=True, right_index=True)
output.index.name = "Tier"
output
# Out:
#        Yearly Cost  Number of Customers
# Tier
# 1     0.000000e+00                 6764
# 2     1.075660e+06                 5526
# 3     0.000000e+00                 4309
# 4     1.739372e+06                 3089
# 5     9.595000e+04                 1919
# 6     0.000000e+00                  681

# %% [markdown]
# ## Output 2
# #### 10 Tier Grouping Output
# <br>
# 3 rows<br>
# 3 fields:<br>
# - Tier<br>
# - Yearly Cost<br>
# - Number of Customers<br>

# %%
# Generating csv output file
output.to_csv("output-202408.csv")
